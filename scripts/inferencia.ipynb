# %%
import sys
from pathlib import Path

# Obtém o caminho do diretório do notebook e sobe um nível para a raiz do projeto
ROOT_DIR = Path().resolve()
ROOT_DIR = ROOT_DIR.parent
CHECKPOINT_PATH = ROOT_DIR / "checkpoints" / "trilha_a_unet_resnet18_seed2028.pth"

if str(ROOT_DIR) not in sys.path:
  sys.path.append(str(ROOT_DIR))

# %%
import src.eval_single_image as eval_single_image

# %%
# --- EXECUÇÃO EM EXEMPLO ---
model = eval_single_image.load_model(CHECKPOINT_PATH)

# Exemplo de entrada: passe o ID da amostra ou o caminho completo
sample_code = ROOT_DIR / "data" / "raw" / "stage1_train" / "0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9" / "images" / "0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9.png"
metrics = eval_single_image.process_single_image(sample_code, model)
# Out:
# C:\Users\T-Gamer\OneDrive\Área de Trabalho\DL_PA1\data\raw\stage1_train\0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9\images\0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 6
#       4 # Exemplo de entrada: passe o ID da amostra ou o caminho completo
#       5 sample_code = ROOT_DIR / "data" / "raw" / "stage1_train" / "0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9" / "images" / "0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9.png"
# ----> 6 metrics = eval_single_image.process_single_image(sample_code, model)
#
# File ~\OneDrive\Área de Trabalho\DL_PA1\src\eval_single_image.py:101, in process_single_image(sample_code, model, raw_dir, device)
#      99 img_paths = list(('images' / sample_folder).glob("*.png"))
#     100 if not img_paths:
# ...
